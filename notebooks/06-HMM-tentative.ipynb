# %%
import numpy as np
import pandas as pd

# %%
import seqlearn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-a5795453f9fd> in <module>()
# ----> 1 import seqlearn
#
# ModuleNotFoundError: No module named 'seqlearn'

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-f327d60d7013> in <module>()
# ----> 1 import imblearn
#
# ModuleNotFoundError: No module named 'imblearn'
